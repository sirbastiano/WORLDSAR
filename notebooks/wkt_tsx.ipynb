# %%
import sys 
sys.path.append('/Users/roberto.delprete/Library/CloudStorage/OneDrive-ESA/Desktop/Repos/WORLDSAR/pyscripts/')
from pathlib import Path


from wkt_utils import terrasar_wkt_extractor

# %%
terrasar_wkt_extractor('/Users/roberto.delprete/Library/CloudStorage/OneDrive-ESA/Desktop/Repos/WORLDSAR/data/TSX/input/dims_op_oc_dfd2_695017442_1/TSX-1.SAR.L1B/TSX1_SAR__MGD_SE___SM_S_SRA_20220523T052620_20220523T052628/TSX1_SAR__MGD_SE___SM_S_SRA_20220523T052620_20220523T052628.xml')
# Out:
# 'POLYGON((13.310909450767731 53.51751643747312, 12.839166784746109 53.567571400363214, 13.158794876162373 53.01888954867456, 12.691449201850668 53.06887496314745, 13.310909450767731 53.51751643747312))'
